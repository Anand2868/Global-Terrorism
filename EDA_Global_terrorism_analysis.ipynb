# %% [markdown]
# <a href="https://colab.research.google.com/github/Anand2868/Global-Terrorism/blob/main/EDA_Global_terrorism_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Project Name**    - **GLOBAL TERRORISM**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# #### Name: Ananda M

# %% [markdown]
# ![image-20170301-5525-1mvs1or.avif](data:image/avif;base64,...)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The project titled "Global Terrorism Analysis" aims to comprehensively analyze and understand the patterns, trends, and characteristics of terrorism incidents worldwide. By leveraging data from reliable sources, the project seeks to provide insights into the various aspects of global terrorism, including its causes, locations, methods, and outcomes. The analysis will facilitate a deeper understanding of the evolving nature of terrorism, aiding policymakers, researchers, and the general public in formulating informed strategies to counter and prevent acts of terrorism
#
#
#    Terrorism is commonly understood to refer to acts of violence that
# target
# civilians in the pursuit of political or ideological aims. In legal terms,
# although the international community has yet to adopt a comprehensive
# definition of terrorism, existing declarations, resolutions and universal
# “sectoral” treaties relating to specific aspects of it define certain acts and
# core elements. In 1994, the General Assembly’s Declaration on Measures
# to Eliminate International Terrorism, set out in its resolution 49/60, stated
# ### Characteristics of the GTD
# Contains information on over 200,000 terrorist attacks
#
# 1. Currently the most comprehensive unclassified database on terrorist attacks in the world
#
# 2.  Currently the most comprehensive unclassified database on terrorist attacks in the world
# 3.  Includes information on more than 88,000 bombings, 19,000 assassinations, and 11,000 kidnappings since 1970
# 4. Includes information on at least 45 variables for each case, with more recent incidents including information on more than 120 variables
# 5. More than 4,000,000 news articles and 25,000 news sources were reviewed to collect incident data from 1998 to 2017 alone

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Terrorism continues to be a grave and complex global issue that poses significant threats to the safety, security, and stability of nations and societies. The problem of global terrorism encompasses a range of challenges and complexities that require comprehensive understanding and effective strategies to address. The problem statement can be summarized as follows:
# 1. Proliferation of Violent Extremism
# 2. Threat to Human Lives
# 3. Destabilization of Societies
# 4. Global Reach and Transnational Networks
# 5. Economic Impact
# 6. Challenge to National Security
# 7. Misuse of Religion and Ideology
# 8. Human Rights Violations
# 9. Cross-Cutting Challenges
# 10. Evolving Tactics and Threat Landscape

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Objective Statement: Our business aims to provide organizations, governments, and institutions with comprehensive terrorism risk assessment services to enhance their preparedness, resilience, and security measures against the threat of global terrorism.
#
# Key Deliverables:
#
# Terrorism Threat Analysis: Conduct in-depth analyses of global and regional terrorism trends, identifying areas of heightened risk and potential hotspots.
#
# Vulnerability Assessment: Evaluate the vulnerabilities of various entities, such as critical infrastructure, public spaces, and high-profile events, to potential terrorist attacks.
#
# Customized Risk Reports: Generate detailed risk assessment reports tailored to the specific needs of clients, providing actionable insights and recommendations.
#
# Security Recommendations: Offer practical security measures and strategies to mitigate identified risks and enhance security protocols.
#
# Training and Education: Provide training programs and workshops to educate clients on recognizing, responding to, and preventing potential terrorism-related threats.
#
# Threat Intelligence Sharing: Facilitate the sharing of timely and relevant threat intelligence to enable proactive measures against emerging terrorist threats.
#
# Collaboration with Authorities: Foster collaboration with law enforcement agencies, government bodies, and international organizations to create a unified approach to countering terrorism.
#
# Crisis Management Planning: Assist clients in developing comprehensive crisis management and response plans to effectively handle terrorism-related incidents.
#
# Benefits and Outcomes:
#
# Enhanced Preparedness: Clients will be better prepared to identify, assess, and respond to terrorism threats, minimizing potential impacts.
#
# Risk Reduction: By implementing recommended security measures, clients can reduce their vulnerability to terrorist attacks and related disruptions.
#
# Global Security Cooperation: Collaborative efforts will contribute to a more coordinated global response to terrorism, improving overall security.
#
# Safer Environments: The services offered will contribute to creating safer environments for individuals, communities, and organizations.
#
# Crisis Mitigation: Clients will be equipped with the tools and strategies to effectively manage and mitigate the consequences of terrorism-related incidents.
#
# Data-Driven Insights: Data analysis and intelligence sharing will enable informed decision-making and adaptive security measures.
#
# Public Confidence: Heightened security measures and proactive risk management can lead to increased public confidence in the safety of various spaces and events.
#
# In summary, the business objective focuses on providing tailored terrorism risk assessment services to help clients proactively address and mitigate the threat of global terrorism. The goal is to contribute to global security efforts by offering expertise, intelligence, and recommendations to minimize the impact of terrorism on individuals, organizations, and society as a whole.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
GTD_df=pd.read_csv('/content/drive/MyDrive/Global terrorism/Global Terrorism Data.csv', encoding='latin-1')
# Out:
# <ipython-input-22-a0b213d13253>:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   GTD_df=pd.read_csv('/content/drive/MyDrive/Global terrorism/Global Terrorism Data.csv', encoding='latin-1')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
GTD_df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
GTD_df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
Terrorism_df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
GTD_df.shape
# Out:
# (181691, 135)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
GTD_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
GTD_df[GTD_df.duplicated()].sum()
# Out:
# eventid       0.0
# iyear         0.0
# imonth        0.0
# iday          0.0
# approxdate    0.0
#              ...
# INT_LOG       0.0
# INT_IDEO      0.0
# INT_MISC      0.0
# INT_ANY       0.0
# related       0.0
# Length: 135, dtype: float64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_GTD_df=GTD_df.isnull()

# %%
# Visualizing the missing values
null_sum_GTD_df=GTD_df[GTD_df.isnull()].sum()
null_sum_GTD_df
# Out:
# eventid       0.0
# iyear         0.0
# imonth        0.0
# iday          0.0
# approxdate      0
#              ...
# INT_LOG       0.0
# INT_IDEO      0.0
# INT_MISC      0.0
# INT_ANY       0.0
# related         0
# Length: 135, dtype: object

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

# %%
# Dataset Describe

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
